# %% [markdown]
# <a href="https://colab.research.google.com/github/indra07-rm/indra07-rm/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # pandas
# Data preprocesing in machine learning using pandas.
#
# 🔗Data preprocessing is required tasks for cleaning the data and making it suitable for a machine learning model which also increases the accuracy and efficiency of a machine learning model.
#
# 🚀pandas is an open source python package that is most widely used for data science/data analysis and machine learning tasks. It is built on top of another package named NumPY, which provides support for multi-dimensional arrays. Preprocessing is the process of doing a pre-analysis of data, in order to transform them into a standard and normalized format.
#
# 💡Preprocesing involves the following aspects:
# - missing values
# - data standardization
# - data normalization
# - data minning

# %%
import pandas as pd

# %%
data = {
    "cars": ["bmw", "tesla", "sizuki", "honda"],
    "models":["2007", "2008", "2009", "2010"],
    "passenger": ["5", "5", "6", "7"]

}
print(data)
data
# Out:
# {'cars': ['bmw', 'tesla', 'sizuki', 'honda'], 'models': ['2007', '2008', '2009', '2010'], 'passenger': ['5', '5', '6', '7']}
# {'cars': ['bmw', 'tesla', 'sizuki', 'honda'],
#  'models': ['2007', '2008', '2009', '2010'],
#  'passenger': ['5', '5', '6', '7']}

# %%
#convert the data into dataframe
df = pd.DataFrame(data)
df
# Out:
#      cars models passenger
# 0     bmw   2007         5
# 1   tesla   2008         5
# 2  sizuki   2009         6
# 3   honda   2010         7

# %%
# save the file as a csv file
df.to_csv("/content/drive/MyDrive/Colab Notebooks/pandas outputcar_data.csv")

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
#panda series
import pandas as pd
a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
#create labels in pandas with index
a = [1, 7, 2]
myvar = pd.Series(a, index=["x", "y", "z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
print(myvar["x"])
# Out:
# 1

# %%
#task: create a dataframe named df, with data calories and duration.
import pandas as pd
data = {
    "calories": [400, 300, 250],
    "duration": [55, 40, 30]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       400        55
# 1       300        40
# 2       250        30

# %%
print(df.loc[1])
# Out:
# calories    300
# duration     40
# Name: 1, dtype: int64

# %%
print(df.loc[1])
# Out:
# calories    300
# duration     40
# Name: 1, dtype: int64

# %%
import pandas as pd
data = {
    "calories": [400, 300, 250],
    "duration": [50, 40, 30]

}
df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
print(df)
# Out:
#       calories  duration
# day1       400        50
# day2       300        40
# day3       250        30

# %%
print(df.loc["day2"])
# Out:
# calories    300
# duration     40
# Name: day2, dtype: int64

# %%
#clean pandas_dataset.cs
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/pandas_dataset.csv")
print(df.to_string())
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
df.head()
# Out:
#    Duration         Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01'    110       130     409.1
# 1        60  2020/12/02'    117       145     479.0
# 2        60  2020/12/03'    103       135     340.0
# 3        45  2020/12/04'    109       175     282.4
# 4        45  2020/12/05'    117       148     406.0

# %%
df.tail()
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 27        60  2020/12/27'     92       118     241.0
# 28        60  2020/12/28'    103       132       NaN
# 29        60  2020/12/29'    100       132     280.0
# 30        60  2020/12/30'    102       129     380.3
# 31        60  2020/12/31'     92       115     243.0

# %%
total_isnull_count = isnull.sum().sum()
print("total number of null values:", isnull_count)
print("total nulls:", total_isnull_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ebc8fae0e030> in <cell line: 0>()
# ----> 1 isnull_count = isnull.sum()
#       2 print("total number of null values:", isnull_count)
#       3 print("total nulls:", total_isnull_count)
#
# NameError: name 'isnull' is not defined

# %%
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
# replace single quote with blank and make the date formated
df["Date"] = df["Date"].replace("'", "", regex = True)
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
# handle null values, return dataframe with no empty cells
# we can use df.dropna(), it removes empty cells but will not chnage the dataframe
# if we want data frame to be chnaged, simply use inplace=True
new_df =df.dropna()
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
isnull_count_newdf = new_df.isnull()

# %%
# another way of handling the null values is by replacing the null values
df.fillna(130, inplace = True)
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/pandas_dataset.csv")
df["Calories"].fillna(130, inplace=True)
df
# Out:
# <ipython-input-25-70e74103b3ad>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"].fillna(130, inplace=True)
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# ...

# %%
# fill specific with mean, median and mode
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/pandas_dataset.csv")
x = df["Calories"].mean()
df["Calories"]. fillna(x, inplace = True)
df
# Out:
# <ipython-input-28-c24ee7a67895>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"]. fillna(x, inplace = True)
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130    409.10
# 1         60  2020/12/02'    117       145    479.00
# 2         60  2020/12/03'    103       135    340.00
# 3         45  2020/12/04'    109       175    282.40
# 4         45  2020/12/05'    117       148    406.00
# 5         60  2020/12/06'    102       127    300.00
# ...
